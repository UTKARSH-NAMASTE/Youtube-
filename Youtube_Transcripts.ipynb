# %% [markdown]
# <a href="https://colab.research.google.com/github/UTKARSH-NAMASTE/Youtube-/blob/main/Youtube_Transcripts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi

YouTubeTranscriptApi.get_transcript("9axlylzP8jQ")
# Out:
# [{'duration': 3.76,
#   'start': 0.08,
#   'text': 'good evening thank you for joining us um'},
#  {'duration': 3.359,
#   'start': 1.92,
#   'text': 'a lot of you wrote to us over the last'},
#  {'duration': 5.28, 'start': 3.84, 'text': '24 hours asking us'},
#  {'duration': 6.001,
#   'start': 5.279,
#   'text': 'what is going on in assam how is it that'},
#  {'duration': 3.519,
#   'start': 9.12,
#   'text': 'state police are actually firing on each'},
#  {'duration': 2.16,
#   'start': 11.28,
#   'text': 'other has anything like this happened'},
#  {'duration': 4.081, 'start': 12.639, 'text': 'before'},
#  {'duration': 4.8,
#   'start': 13.44,
#   'text': "uh i'm shocked azuva quite frankly um"},
#  {'duration': 3.36,
#   'start': 16.72,
#   'text': "i'm not his experience to some of the"},
#  {'duration': 4.56,
#   'start': 18.24,
#   'text': 'other journalists we speak to on'},
#  {'duration': 4.56,
#   'start': 20.08,
#   'text': "this uh show so i've never come across"},
# ...

# %%
transcript_list = YouTubeTranscriptApi.list_transcripts("9axlylzP8jQ")
transcript = transcript_list.find_transcript(['de', 'en'])
transcript.fetch()
# Out:
# [{'duration': 3.76,
#   'start': 0.08,
#   'text': 'good evening thank you for joining us um'},
#  {'duration': 3.359,
#   'start': 1.92,
#   'text': 'a lot of you wrote to us over the last'},
#  {'duration': 5.28, 'start': 3.84, 'text': '24 hours asking us'},
#  {'duration': 6.001,
#   'start': 5.279,
#   'text': 'what is going on in assam how is it that'},
#  {'duration': 3.519,
#   'start': 9.12,
#   'text': 'state police are actually firing on each'},
#  {'duration': 2.16,
#   'start': 11.28,
#   'text': 'other has anything like this happened'},
#  {'duration': 4.081, 'start': 12.639, 'text': 'before'},
#  {'duration': 4.8,
#   'start': 13.44,
#   'text': "uh i'm shocked azuva quite frankly um"},
#  {'duration': 3.36,
#   'start': 16.72,
#   'text': "i'm not his experience to some of the"},
#  {'duration': 4.56,
#   'start': 18.24,
#   'text': 'other journalists we speak to on'},
#  {'duration': 4.56,
#   'start': 20.08,
#   'text': "this uh show so i've never come across"},
# ...
